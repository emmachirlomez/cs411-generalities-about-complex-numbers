# %% [markdown]
# # Welcome to Generalities about Complex Numbers !
# ---

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #83C5BE;background-color:#F3F3F3;">
#     <span style="text-decoration:underline;font-weight:bold;">How to use this notebook?</span><br/>
#     <br/>In this activity, you will try to solve quadratic equations in a <strong>graphical way.</strong><br/>
#     To be able to interact with the graphics, please press the ">>" button at the top of the page, and click on restart when the pop up appears.<br/><br/>
# <img src="images/instruction_help_IPS.jpeg" alt="You do not have access to this content. Try logging in." style="width:800px;"/>
#
# </div>

# %% [markdown]
# ---
# *Exercise 1*: What are the solutions to the following quadratic equation?
#
# $$
# \begin{aligned}
# x^{2} + 2x - 15 = 0
# \end{aligned}
# $$
#
# <div style="padding:8px 0 8px 15px;border-left:3px solid #B51F1F;background-color:#F3F3F3;">
#     <span style="font-weight:bold;text-decoration:underline;">Activity</span><br/>
#
# Try to answer this question *without* solving it on paper.
# <br>
# Instead, use the following graph to find the solutions.
# <br>
# When you find the correct answer, please fill in the inputs below the graph.
#
# </div>

# %% [markdown]
# <div style="padding:10px 0 2px 15px;border-left:3px solid black;background-color:#F3F3F3;">
#
# **Hint** - Try to use the **x_value** slider to help you find the correct solutions.
#
# </div>

# %% [markdown]
# <div style="padding:10px 0 2px 15px;border-left:3px solid black;background-color:#F3F3F3;">
#
# **Hint** - Take care at how the red and green dots interact when you found a solution, it will be useful in the next questions when it will become a little more difficult.
#
# </div>

# %%
# %matplotlib widget
import psi_helper
psi_helper.exercise_1()
# Out:
# interactive(children=(IntSlider(value=0, description='x_value', max=10, min=-10), Output()), _dom_classes=('wi…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Enter the solutions for *Exercise 1* below:

# %%
psi_helper.real_quadratic_eq_input()
# Out:
# Textarea(value='', description='Solution x1:', placeholder='Type something')
# Textarea(value='', description='Solution x2:', placeholder='Type something')

# %% [markdown]
# ---
# *Exercise 2*:
# By applying the same solving method as in *Exercise 1*, try to find the solutions to the equation bellow.
#
# $$
# \begin{aligned}
# x^{2} + 1 = 0
# \end{aligned}
# $$

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #B51F1F;background-color:#F3F3F3;">
#     <span style="font-weight:bold;text-decoration:underline;">Activity</span><br/>
# Carefully observe how the values on the sliders interact with the plots.
# <br>
# Compare the results you get by computing the solutions on paper with the values of the sliders.
# <br>
# When you find the correct answer, please fill in the inputs below the graph.
#
# </div>

# %% [markdown]
# <div style="padding:10px 0 2px 15px;border-left:3px solid black;background-color:#F3F3F3;">
#
# **Hint** - This time, things are getting a bit more complciated.
# <br>
# Try to find the solutions by using the 2 sliders below **real_part** and **imag_part**(imaginary part)
#
# </div>

# %%
psi_helper.exercise_2()
# Out:
# interactive(children=(IntSlider(value=0, description='real_part', max=10, min=-10), IntSlider(value=0, descrip…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Enter the **Real** and **Imaginary** parts of solution x1:

# %%
psi_helper.complex_eq_input()
# Out:
# Textarea(value='', description='Real:', placeholder='Type something')
# Textarea(value='', description='Imaginary:', placeholder='Type something')

# %% [markdown]
# Enter the **Real** and **Imaginary** parts of solution x2:

# %%
psi_helper.complex_eq_input()
# Out:
# Textarea(value='', description='Real:', placeholder='Type something')
# Textarea(value='', description='Imaginary:', placeholder='Type something')

# %% [markdown]
# ---
# *Exercise 3*: What are the solutions to the following quadratic equation?
#
# $$
# \begin{aligned}
# x^{2} + 8x + 12 = 0
# \end{aligned}
# $$
#
# <div style="padding:8px 0 8px 15px;border-left:3px solid #B51F1F;background-color:#F3F3F3;">
#     <span style="font-weight:bold;text-decoration:underline;">Activity</span><br/>
# Just as before, compare the results you get by computing the solutions on paper with the values of the sliders.
# <br>
# When you find the correct answer, please fill in the inputs below the graph.
#
# </div>

# %%
psi_helper.exercise_3()
# Out:
# interactive(children=(IntSlider(value=0, description='real_part', max=10, min=-10), IntSlider(value=0, descrip…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Enter the **Real** and **Imaginary** parts of solution x1:

# %%
psi_helper.complex_eq_input()
# Out:
# Textarea(value='', description='Real:', placeholder='Type something')
# Textarea(value='', description='Imaginary:', placeholder='Type something')

# %% [markdown]
# Enter the **Real** and **Imaginary** parts of solution x2:

# %%
psi_helper.complex_eq_input()
# Out:
# Textarea(value='', description='Real:', placeholder='Type something')
# Textarea(value='', description='Imaginary:', placeholder='Type something')

# %% [markdown]
# ---
#
# As you've seen, the Complex Space has one more dimension than the Real Space, the **Imaginary Part**.
# <br>
# Here is how the function $x^{2} + 1$ looks like if we plot it with the help of this new dimension.

# %% [markdown]
# <div style="padding:10px 0 2px 15px;border-left:3px solid black;background-color:#F3F3F3;">
#
# **Hint** - You can interact with the plot and turn it around :).
#
# </div>

# %%
psi_helper.fun_fact()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---
# <div style="padding:8px 0 8px 15px;border-left:3px solid #83C5BE;background-color:#F3F3F3;">
#     <span style="font-weight:bold;text-decoration:underline;">End of activity</span><br/>
#
# This is the end of the activity, please go back to the Moodle course.
#
# </div>
